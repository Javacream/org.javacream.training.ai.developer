// %% [markdown]
// # Block 5: RAG mit Spring AI
//
// **Lernziel:** Die Teilnehmenden bauen aus Retrieval und ChatClient eine vollständige RAG-Anwendung und können typische Qualitätsprobleme systematisch analysieren.
//
// Dieses Notebook ist für ein Java/Spring-AI-Seminar ausgelegt. Codezellen verwenden Java-Syntax und können mit einem Java-Kernel wie IJava ausgeführt oder in das zugehörige Maven-Projekt übertragen werden.

// %% [markdown]
// ## Arbeitsweise
//
// Bearbeite die Aufgaben in Reihenfolge. Starte das zugehörige Maven-Projekt bei Bedarf separat. Zugangsdaten niemals in das Notebook schreiben; verwende `OPENAI_API_KEY`.

// %% [markdown]
// ## Aufgabe 1: RAG-Advisor einsetzen
//
// Binde den VectorStore mit QuestionAnswerAdvisor in den ChatClient ein.

// %%
ChatClient ragClient = ChatClient.builder(chatModel)
    .defaultAdvisors(QuestionAnswerAdvisor.builder(vectorStore).build())
    .build();

// %% [markdown]
// **Erläuterung:** Die Musterlösung zeigt eine kompakte Referenzimplementierung. Prüfe bei modellabhängigen Aufgaben zusätzlich Fehlerszenarien und alternative Modellantworten.

// %% [markdown]
// ## Aufgabe 2: Grounded Prompting
//
// Gib der Anwendung vor, nur auf Basis der Wissensbasis zu antworten und Wissenslücken explizit zu benennen.

// %%
String answer = ragClient.prompt()
    .system("Antworte nur anhand des bereitgestellten Kontexts. Wenn er nicht reicht, sage: 'Dazu enthält die Wissensbasis keine ausreichende Information.'")
    .user("Was ist ein VectorStore?")
    .call()
    .content();

// %% [markdown]
// **Erläuterung:** Die Musterlösung zeigt eine kompakte Referenzimplementierung. Prüfe bei modellabhängigen Aufgaben zusätzlich Fehlerszenarien und alternative Modellantworten.

// %% [markdown]
// ## Aufgabe 3: Quellen sichtbar machen
//
// Ergänze Metadaten so, dass sich gefundene Dokumente fachlich nachvollziehen lassen.

// %%
Document d = new Document(
    "QuestionAnswerAdvisor implementiert einen einfachen RAG-Ablauf.",
    Map.of("source","spring-ai-notes", "chapter","rag"));
vectorStore.add(List.of(d));
// Die Metadaten der Retrieval-Treffer können für Quellenanzeige weiterverarbeitet werden.

// %% [markdown]
// **Erläuterung:** Die Musterlösung zeigt eine kompakte Referenzimplementierung. Prüfe bei modellabhängigen Aufgaben zusätzlich Fehlerszenarien und alternative Modellantworten.

// %% [markdown]
// ## Aufgabe 4: Fehleranalyse
//
// Teste mindestens eine Frage mit guter, eine mit schwacher und eine ohne passende Retrieval-Grundlage.

// %%
List<String> questions = List.of(
    "Welche Aufgabe hat ein VectorStore?",
    "Welche Datenbank ist immer die beste für RAG?",
    "Wer gewann die Fußball-WM 2038?"
);
questions.forEach(q -> System.out.println(
    ragClient.prompt().user(q).call().content()
));

// %% [markdown]
// **Erläuterung:** Die Musterlösung zeigt eine kompakte Referenzimplementierung. Prüfe bei modellabhängigen Aufgaben zusätzlich Fehlerszenarien und alternative Modellantworten.

// %% [markdown]
// ## Abschluss
//
// Vergleiche deine Lösung mit dem ausführbaren Maven-Projekt. Notiere mindestens eine Verbesserung, die du für einen produktiven Einsatz vornehmen würdest.
