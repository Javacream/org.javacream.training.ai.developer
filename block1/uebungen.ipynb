// %% [markdown]
// # Block 1: Generative AI und Spring AI verstehen
//
// **Lernziel:** Die Teilnehmenden verstehen das Grundmodell generativer AI, die wichtigsten Spring-AI-Abstraktionen und können einen ersten Modellaufruf aus einer Spring-Boot-Anwendung durchführen.
//
// Dieses Notebook ist für ein Java/Spring-AI-Seminar ausgelegt. Codezellen verwenden Java-Syntax und können mit einem Java-Kernel wie IJava ausgeführt oder in das zugehörige Maven-Projekt übertragen werden.

// %% [markdown]
// ## Arbeitsweise
//
// Bearbeite die Aufgaben in Reihenfolge. Starte das zugehörige Maven-Projekt bei Bedarf separat. Zugangsdaten niemals in das Notebook schreiben; verwende `OPENAI_API_KEY`.

// %% [markdown]
// ## Aufgabe 1: Architektur zuordnen
//
// Ordne ChatClient, ChatModel, Provider und LLM in eine Aufrufkette ein und erkläre die Verantwortlichkeit jeder Schicht.

// %%
// Skizziere als Kommentar die Aufrufkette:
// Anwendung -> ... -> ... -> Provider -> LLM

// %% [markdown]
// **Reflexion:** Was ist an dieser Lösung deterministisch, und wo hängt das Verhalten vom Modell oder von externen Diensten ab?

// %% [markdown]
// ## Aufgabe 2: Projekt konfigurieren
//
// Ergänze eine Spring-Boot-Anwendung um den OpenAI-Starter und konfiguriere den API-Key ausschließlich über eine Umgebungsvariable.

// %%
// TODO: Konfiguration erfolgt in application.properties.
// API-Key NICHT hier eintragen.
String apiKeyEnv = "OPENAI_API_KEY";

// %% [markdown]
// **Reflexion:** Was ist an dieser Lösung deterministisch, und wo hängt das Verhalten vom Modell oder von externen Diensten ab?

// %% [markdown]
// ## Aufgabe 3: Ersten Modellaufruf implementieren
//
// Erzeuge einen ChatClient und stelle eine kurze fachliche Frage an das Modell.

// %%
// TODO: ChatClient injizieren und einen Prompt ausführen.
String question = "Erkläre Spring AI in drei Sätzen.";

// %% [markdown]
// **Reflexion:** Was ist an dieser Lösung deterministisch, und wo hängt das Verhalten vom Modell oder von externen Diensten ab?

// %% [markdown]
// ## Aufgabe 4: Metadaten untersuchen
//
// Lass dir zusätzlich zur Textantwort das ChatResponse-Objekt geben und untersuche verfügbare Metadaten.

// %%
// TODO: Statt nur content() ein ChatResponse abrufen
// und die Metadaten im Debugger untersuchen.

// %% [markdown]
// **Reflexion:** Was ist an dieser Lösung deterministisch, und wo hängt das Verhalten vom Modell oder von externen Diensten ab?

// %% [markdown]
// ## Abschluss
//
// Vergleiche deine Lösung mit dem ausführbaren Maven-Projekt. Notiere mindestens eine Verbesserung, die du für einen produktiven Einsatz vornehmen würdest.
