// %% [markdown]
// # Block 7: MCP, Security und Guardrails
//
// **Lernziel:** Die Teilnehmenden verstehen MCP als standardisierte Integrationsschicht und können zentrale Schutzmaßnahmen für Prompts, RAG und Tool-Nutzung praktisch umsetzen.
//
// Dieses Notebook ist für ein Java/Spring-AI-Seminar ausgelegt. Codezellen verwenden Java-Syntax und können mit einem Java-Kernel wie IJava ausgeführt oder in das zugehörige Maven-Projekt übertragen werden.

// %% [markdown]
// ## Arbeitsweise
//
// Bearbeite die Aufgaben in Reihenfolge. Starte das zugehörige Maven-Projekt bei Bedarf separat. Zugangsdaten niemals in das Notebook schreiben; verwende lokale Ollama-Installation.

// %% [markdown]
// ## Aufgabe 1: MCP einordnen
//
// Skizziere, welche Verantwortlichkeiten bei einem MCP Client, MCP Server und ChatClient liegen.

// %%
// Skizze:
// ChatClient -> MCP Client -> MCP Server -> Tool/Resource
// Ergänze Verantwortlichkeiten.

// %% [markdown]
// **Reflexion:** Was ist an dieser Lösung deterministisch, und wo hängt das Verhalten vom Modell oder von externen Diensten ab?

// %% [markdown]
// ## Aufgabe 2: Input Guardrail
//
// Implementiere eine einfache Eingabeprüfung für offensichtlich unerlaubte oder manipulative Anweisungen.

// %%
// TODO: rejectReason(String input) implementieren.
// Nicht versuchen, Prompt Injection vollständig per Keyword-Liste zu lösen.

// %% [markdown]
// **Reflexion:** Was ist an dieser Lösung deterministisch, und wo hängt das Verhalten vom Modell oder von externen Diensten ab?

// %% [markdown]
// ## Aufgabe 3: Tool Allowlist
//
// Stelle nur explizit freigegebene Tools für einen Anwendungsfall bereit.

// %%
// TODO: Erzeuge explizit nur die ToolCallbacks, die für den Use Case freigegeben sind.

// %% [markdown]
// **Reflexion:** Was ist an dieser Lösung deterministisch, und wo hängt das Verhalten vom Modell oder von externen Diensten ab?

// %% [markdown]
// ## Aufgabe 4: MCP-Server vorbereiten
//
// Expose ein ungefährliches read-only Werkzeug als MCP Tool und dokumentiere die Sicherheitsgrenze des HTTP-Endpunkts.

// %%
// TODO: Ein read-only MCP Tool definieren.
// HTTP-MCP-Endpunkte benötigen vor externer Exposition eine Sicherheitsgrenze.

// %% [markdown]
// **Reflexion:** Was ist an dieser Lösung deterministisch, und wo hängt das Verhalten vom Modell oder von externen Diensten ab?

// %% [markdown]
// ## Abschluss
//
// Vergleiche deine Lösung mit dem ausführbaren Maven-Projekt. Notiere mindestens eine Verbesserung, die du für einen produktiven Einsatz vornehmen würdest.
