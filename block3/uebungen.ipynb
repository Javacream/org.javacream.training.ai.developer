// %% [markdown]
// # Block 3: Advisors und Conversation Memory
//
// **Lernziel:** Die Teilnehmenden verstehen Advisors als wiederverwendbare Verarbeitungsschicht und können Conversation Memory sauber über Conversation IDs verwalten.
//
// Dieses Notebook ist für ein Java/Spring-AI-Seminar ausgelegt. Codezellen verwenden Java-Syntax und können mit einem Java-Kernel wie IJava ausgeführt oder in das zugehörige Maven-Projekt übertragen werden.

// %% [markdown]
// ## Arbeitsweise
//
// Bearbeite die Aufgaben in Reihenfolge. Starte das zugehörige Maven-Projekt bei Bedarf separat. Zugangsdaten niemals in das Notebook schreiben; verwende lokale Ollama-Installation.

// %% [markdown]
// ## Aufgabe 1: Memory konfigurieren
//
// Erzeuge ein MessageWindowChatMemory mit einem begrenzten Nachrichtenfenster.

// %%
// TODO: MessageWindowChatMemory mit maxMessages(10) erzeugen.

// %% [markdown]
// **Reflexion:** Was ist an dieser Lösung deterministisch, und wo hängt das Verhalten vom Modell oder von externen Diensten ab?

// %% [markdown]
// ## Aufgabe 2: Memory Advisor einbinden
//
// Registriere einen MessageChatMemoryAdvisor am ChatClient.

// %%
// TODO: MessageChatMemoryAdvisor am ChatClient registrieren.

// %% [markdown]
// **Reflexion:** Was ist an dieser Lösung deterministisch, und wo hängt das Verhalten vom Modell oder von externen Diensten ab?

// %% [markdown]
// ## Aufgabe 3: Conversation IDs
//
// Implementiere einen REST-Endpunkt, der eine conversationId entgegennimmt und getrennte Unterhaltungen ermöglicht.

// %%
String conversationId = "demo-1";
// TODO: bei jedem Call über ChatMemory.CONVERSATION_ID setzen.

// %% [markdown]
// **Reflexion:** Was ist an dieser Lösung deterministisch, und wo hängt das Verhalten vom Modell oder von externen Diensten ab?

// %% [markdown]
// ## Aufgabe 4: Advisor ergänzen
//
// Füge Logging über einen Advisor hinzu und erläutere, warum sensible Inhalte nicht ungefiltert geloggt werden sollten.

// %%
// TODO: SimpleLoggerAdvisor ergänzen.
// Welche Daten dürfen in Produktion nicht geloggt werden?

// %% [markdown]
// **Reflexion:** Was ist an dieser Lösung deterministisch, und wo hängt das Verhalten vom Modell oder von externen Diensten ab?

// %% [markdown]
// ## Abschluss
//
// Vergleiche deine Lösung mit dem ausführbaren Maven-Projekt. Notiere mindestens eine Verbesserung, die du für einen produktiven Einsatz vornehmen würdest.
